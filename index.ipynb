# %%
import requests
from IPython.core.display import HTML
HTML(f"""
<style>
@import "https://cdn.jsdelivr.net/npm/bulma@0.9.4/css/bulma.min.css";
</style>
""")

# %% [markdown]
# # Welcome to the IML content page
# While LearnIT should serve as your primary reference for the "Introduction to Machine Learning." course at ITU. This webpage  contains the majority of the assignments, exercises, tutorials, and additional material used during the course.
# The site is divided into the following sections:
# - **Course Guidelines** contains practical information about the course, prerequsite material and references to reading material needed for the course.
# - **Python** contains practical information on how to use this website as well as material on how to use Python and Jupyter Notebooks.
# - **Exercises** contains weekly exercises and assignments.
# - **Tutorials** contains tutorials for associated to specific lectures.
# - **Explorer**  Contains an experimental interactive tool used in the lectures and which you can experiment with outside the lectures. Notice the tool is not scalable to many simultanious users.
#
# The majority of exercise and tutorial content is provided in the form of Jupyter Notebooks which are autogenerated for display in this webpage. You need to download and interact with these notebooks on your own computer for the exercises.
# <!--
# <h2 style="color: red;">Do this first!!</h2>
# Overview/Important Information
#   -->
